# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# Cargar los datos
players_15 = pd.read_csv('/content/drive/My Drive/Colab Notebooks/fifa2020/players_15.csv')
players_16 = pd.read_csv('/content/drive/My Drive/Colab Notebooks/fifa2020/players_16.csv')
players_17 = pd.read_csv('/content/drive/My Drive/Colab Notebooks/fifa2020/players_17.csv')
players_18 = pd.read_csv('/content/drive/My Drive/Colab Notebooks/fifa2020/players_18.csv')
players_19 = pd.read_csv('/content/drive/My Drive/Colab Notebooks/fifa2020/players_19.csv')
players_20 = pd.read_csv('/content/drive/My Drive/Colab Notebooks/fifa2020/players_20.csv')
teams = pd.read_csv('/content/drive/My Drive/Colab Notebooks/fifa2020/teams_and_leagues.csv')


# Ver las primeras filas para cada dataset
print(players_15.head())
print(players_16.head())
print(players_17.head())
print(players_18.head())
print(players_19.head())
print(players_20.head())
print(teams.head())
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2       9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3      41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4     167495  https://sofifa.com/player/167495/manuel-neuer/...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   27  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29  1985-02-05
# 2          A. Robben                         Arjen Robben   30  1984-01-23
# 3     Z. Ibrahimović                   Zlatan Ibrahimović   32  1981-10-03
# 4           M. Neuer                         Manuel Neuer   28  1986-03-27
#
#    height_cm  weight_kg  nationality                 club  ...   lwb   ldm  \
# ...

# %%
# Inspección de los tipos de datos y la cantidad de valores nulos
print(players_15.info())
print(players_16.info())
print(players_17.info())
print(players_18.info())
print(players_19.info())
print(players_20.info())
print(teams.info())


# Verificar valores nulos en los datasets
print(players_15.isnull().sum())
print(players_16.isnull().sum())
print(players_17.isnull().sum())
print(players_18.isnull().sum())
print(players_19.isnull().sum())
print(players_20.isnull().sum())
print(teams.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15465 entries, 0 to 15464
# Columns: 104 entries, sofifa_id to rb
# dtypes: float64(17), int64(11), object(76)
# memory usage: 12.3+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14881 entries, 0 to 14880
# Columns: 104 entries, sofifa_id to rb
# dtypes: float64(17), int64(11), object(76)
# memory usage: 11.8+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17009 entries, 0 to 17008
# Columns: 104 entries, sofifa_id to rb
# dtypes: float64(16), int64(12), object(76)
# memory usage: 13.5+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17592 entries, 0 to 17591
# Columns: 104 entries, sofifa_id to rb
# dtypes: float64(16), int64(11), object(77)
# memory usage: 14.0+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17770 entries, 0 to 17769
# Columns: 104 entries, sofifa_id to rb
# dtypes: float64(16), int64(11), object(77)
# memory usage: 14.1+ MB
# None
# ...

# %%
# Descripción estadística de los datos numéricos
print(players_15.describe())
print(players_16.describe())
print(players_17.describe())
print(players_18.describe())
print(players_19.describe())
print(players_20.describe())
# Out:
#            sofifa_id           age     height_cm     weight_kg       overall  \
# count   15465.000000  15465.000000  15465.000000  15465.000000  15465.000000
# mean   189298.588425     24.763272    181.093631     75.482703     63.948594
# std     39648.820272      4.624565      6.635182      6.907243      7.208610
# min         2.000000     16.000000    155.000000     50.000000     40.000000
# 25%    178043.000000     21.000000    176.000000     70.000000     59.000000
# 50%    200844.000000     24.000000    181.000000     75.000000     64.000000
# 75%    214326.000000     28.000000    186.000000     80.000000     69.000000
# max    225562.000000     44.000000    203.000000    110.000000     93.000000
#
#           potential  value_eur  wage_eur  international_reputation  \
# count  15465.000000    15465.0   15465.0              15465.000000
# mean      68.483091        0.0       0.0                  1.126350
# std        6.611708        0.0       0.0                  0.401362
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Distribución de la edad de los jugadores
plt.figure(figsize=(10, 6))
sns.histplot(players_15['age'], kde=True, color='blue', bins=30)
plt.title('Distribución de Edades (Players 15)')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# En esta grafica podemos observar los rangos de edad en que hay mas jugadores estan comprendidos entre los 20 y 25 años de edad

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Distribución de la edad de los jugadores
plt.figure(figsize=(10, 6))
sns.histplot(players_16['age'], kde=True, color='blue', bins=30)
plt.title('Distribución de Edades (Players 16)')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.show()

# %%
# Análisis de correlación entre valor y habilidades (ejemplo con una variable de habilidades)
correlation = players_16[['overall', 'potential', 'value_eur']].corr()
print(correlation)

# Visualización de la correlación
sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.title('Correlación entre Habilidades y Valor de los Jugadores')
plt.show()
# Out:
#             overall  potential  value_eur
# overall    1.000000   0.781817   0.598158
# potential  0.781817   1.000000   0.576793
# value_eur  0.598158   0.576793   1.000000

# %% [markdown]
# Interpretación de la Correlación:
# Correlación entre overall y potential = 0.78
# Esto indica una fuerte correlación positiva, indicando que hay una relación bastante fuerte entre overall y el potencial potential. Por lo que podemos indicar que los  jugadores que tienen un overall más alto tienden a tener un mayor potencial de desarrollo. En pocas palabras los jugadores considerados mas habilidosos en el presente generalmente tienen un alto potencial de crecimiento futuro.
#
# Correlación entre overall y value_eur = 0.60
# Es una correlacion moderada  entre el valor  y la calificación general overall. Los jugadores con una mayor calificación general tienden a tener un valor de mercado más alto, lo cual tiene sentido, ya que los jugadores más habilidosos suelen ser más caros.
#
# Correlación entre potential y value_eur = 0.58
# Este tambien nos indica una correlacion moderada positiva en este caso entre el potencial de un jugador y su valor. Esto sugiere que los jugadores con un alto potencial aun que no tengan un overall alto,  todavía pueden tener un valor de mercado elevado debido a su capacidad para mejorar en el futuro.
#
#
# Sin embargo es importante hacer enfasis en que La calificación general el overall de un jugador es importante  para determinar su valor de mercado.

# %%
# Filtrar los clubes con reputación internacional alta (por ejemplo, reputación > 75)
top_clubs = players_16[players_16['international_reputation'] > 3]

# Boxplot de la distribución del valor de mercado por club en los mejores clubes
plt.figure(figsize=(12, 8))
sns.boxplot(x='club', y='value_eur', data=top_clubs)
plt.title('Distribución del Valor de Mercado por Club (Top Clubs)')
plt.xlabel('Club')
plt.ylabel('Valor de Mercado (EUR)')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# observando la mediana notamos  FCBarcelona y Real Madrid tienen  un valor de mercado más alto en general.
# Par el Real Madrid podría indicar que hay jugadores estrella con un valor de mercado mucho más alto que el resto.

# %%
# Correlación entre la edad y el valor de mercado
correlation = players_16[['age', 'value_eur']].corr()
print(correlation)
# Out:
#                 age  value_eur
# age        1.000000   0.079883
# value_eur  0.079883   1.000000

# %% [markdown]
# 0.079883 es una correlación muy baja, por lo que podriamos decir que sugiere que no hay una relación lineal fuerte entre la edad de los jugadores y su valor de mercado.

# %%
# Correlación entre la edad y el valor de mercado
correlation = players_17[['age', 'value_eur']].corr()
print(correlation)
# Out:
#                age  value_eur
# age        1.00000    0.08309
# value_eur  0.08309    1.00000

# %%
# Correlación entre la edad y el valor de mercado
correlation = players_18[['age', 'value_eur']].corr()
print(correlation)
# Out:
#                 age  value_eur
# age        1.000000   0.081852
# value_eur  0.081852   1.000000

# %%
# Correlación entre la edad y el valor de mercado
correlation = players_19[['age', 'value_eur']].corr()
print(correlation)
# Out:
#                 age  value_eur
# age        1.000000   0.082805
# value_eur  0.082805   1.000000

# %%
# Correlación entre la edad y el valor de mercado
correlation = players_20[['age', 'value_eur']].corr()
print(correlation)
# Out:
#                 age  value_eur
# age        1.000000   0.081513
# value_eur  0.081513   1.000000

# %% [markdown]
# **DATA CEANING**

# %%
# Verificar si hay duplicados
duplicados = players_15.duplicated().sum()
print(f"Duplicados encontrados en player_16: {duplicados}")

# Eliminar los duplicados
player_16 = players_15.drop_duplicates()

# Verificar que ya no existen duplicados
duplicados = players_15.duplicated().sum()
print(f"Duplicados después de la limpieza: {duplicados}")
# Out:
# Duplicados encontrados en player_16: 0
# Duplicados después de la limpieza: 0

# %%
duplicados = players_17.duplicated().sum()
print(f"Duplicados encontrados en player_16: {duplicados}")

player_16 = players_17.drop_duplicates()

duplicados = players_17.duplicated().sum()
print(f"Duplicados después de la limpieza: {duplicados}")




duplicados = players_18.duplicated().sum()
print(f"Duplicados encontrados en player_16: {duplicados}")

player_16 = players_18.drop_duplicates()

duplicados = players_18.duplicated().sum()
print(f"Duplicados después de la limpieza: {duplicados}")



duplicados = players_19.duplicated().sum()
print(f"Duplicados encontrados en player_16: {duplicados}")

player_16 = players_19.drop_duplicates()

duplicados = players_19.duplicated().sum()
print(f"Duplicados después de la limpieza: {duplicados}")



duplicados = players_20.duplicated().sum()
print(f"Duplicados encontrados en player_16: {duplicados}")

player_16 = players_20.drop_duplicates()

duplicados = players_20.duplicated().sum()
print(f"Duplicados después de la limpieza: {duplicados}")
# Out:
# Duplicados encontrados en player_16: 0
# Duplicados después de la limpieza: 0
# Duplicados encontrados en player_16: 0
# Duplicados después de la limpieza: 0
# Duplicados encontrados en player_16: 0
# Duplicados después de la limpieza: 0
# Duplicados encontrados en player_16: 0
# Duplicados después de la limpieza: 0

# %%
# Verificar los valores nulos en las columnas
valores_nulos = players_15.isnull().sum()
print("Valores nulos por columna:\n", valores_nulos)

valores_nulos = players_16.isnull().sum()
print("Valores nulos por columna:\n", valores_nulos)

valores_nulos = players_17.isnull().sum()
print("Valores nulos por columna:\n", valores_nulos)

valores_nulos = players_18.isnull().sum()
print("Valores nulos por columna:\n", valores_nulos)
valores_nulos = players_19.isnull().sum()
print("Valores nulos por columna:\n", valores_nulos)

valores_nulos = players_20.isnull().sum()
print("Valores nulos por columna:\n", valores_nulos)
# Out:
# Valores nulos por columna:
#  sofifa_id        0
# player_url       0
# short_name       0
# long_name        0
# age              0
#               ...
# lb            1703
# lcb           1703
# cb            1703
# rcb           1703
# rb            1703
# Length: 104, dtype: int64
# Valores nulos por columna:
#  sofifa_id        0
# player_url       0
# short_name       0
# long_name        0
# age              0
#               ...
# lb            1618
# lcb           1618
# cb            1618
# rcb           1618
# rb            1618
# Length: 104, dtype: int64
# Valores nulos por columna:
#  sofifa_id        0
# player_url       0
# short_name       0
# long_name        0
# age              0
#               ...
# lb            1925
# lcb           1925
# cb            1925
# rcb           1925
# rb            1925
# Length: 104, dtype: int64
# Valores nulos por columna:
#  sofifa_id        0
# player_url       0
# short_name       0
# long_name        0
# age              0
# ...

# %%
# Verificar los tipos de datos de las columnas
print(players_15.dtypes)

print(players_16.dtypes)

print(players_17.dtypes)

print(players_18.dtypes)

print(players_19.dtypes)

print(players_20.dtypes)
# Out:
# sofifa_id      int64
# player_url    object
# short_name    object
# long_name     object
# age            int64
#                ...
# lb            object
# lcb           object
# cb            object
# rcb           object
# rb            object
# Length: 104, dtype: object
# sofifa_id      int64
# player_url    object
# short_name    object
# long_name     object
# age            int64
#                ...
# lb            object
# lcb           object
# cb            object
# rcb           object
# rb            object
# Length: 104, dtype: object
# sofifa_id      int64
# player_url    object
# short_name    object
# long_name     object
# age            int64
#                ...
# lb            object
# lcb           object
# cb            object
# rcb           object
# rb            object
# Length: 104, dtype: object
# sofifa_id      int64
# player_url    object
# short_name    object
# long_name     object
# age            int64
#                ...
# lb            object
# ...

# %%
# Estandarizar nombres de clubes (minúsculas)
players_15['club'] = players_16['club'].str.lower()

players_16['club'] = players_16['club'].str.lower()
players_17['club'] = players_17['club'].str.lower()
players_18['club'] = players_18['club'].str.lower()
players_19['club'] = players_19['club'].str.lower()
players_20['club'] = players_20['club'].str.lower()

# %%
print(players_15.info())
print(players_16.info())
print(players_17.info())
print(players_18.info())
print(players_19.info())
print(players_20.info())




print(players_15.head())
print(players_16.head())
print(players_17.head())
print(players_18.head())
print(players_19.head())
print(players_20.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15465 entries, 0 to 15464
# Columns: 104 entries, sofifa_id to rb
# dtypes: float64(17), int64(11), object(76)
# memory usage: 12.3+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14881 entries, 0 to 14880
# Columns: 104 entries, sofifa_id to rb
# dtypes: float64(17), int64(11), object(76)
# memory usage: 11.8+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17009 entries, 0 to 17008
# Columns: 104 entries, sofifa_id to rb
# dtypes: float64(16), int64(12), object(76)
# memory usage: 13.5+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17592 entries, 0 to 17591
# Columns: 104 entries, sofifa_id to rb
# dtypes: float64(16), int64(11), object(77)
# memory usage: 14.0+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17770 entries, 0 to 17769
# Columns: 104 entries, sofifa_id to rb
# dtypes: float64(16), int64(11), object(77)
# memory usage: 14.1+ MB
# None
# ...

# %% [markdown]
# **DATA WRANGILING**

# %%
# Crear una nueva variable que sea la relación entre salario y valor de mercado
players_16['salario_valor_ratio'] = players_16['wage_eur'] / players_16['value_eur']

# Mostrar las primeras filas para verificar
players_16[['short_name', 'wage_eur', 'value_eur', 'salario_valor_ratio']].head()
# Out:
#           short_name  wage_eur  value_eur  salario_valor_ratio
# 0           L. Messi    550000  111000000             0.004955
# 1  Cristiano Ronaldo    475000   85500000             0.005556
# 2          A. Robben    250000   56000000             0.004464
# 3           M. Neuer    250000   58000000             0.004310
# 4          L. Suárez    300000   69000000             0.004348

# %%
# Eliminar las filas con NaN o inf en la columna 'salario_valor_ratio'
players_16_clean = players_16.dropna(subset=['salario_valor_ratio'])

# Verificar si se han eliminado correctamente las filas
print(players_16_clean['salario_valor_ratio'].isna().sum())
# Out:
# 0

# %%
print(players_16['salario_valor_ratio'].describe())
# Out:
# count    14656.000000
# mean         0.010015
# std          0.006742
# min          0.000200
# 25%          0.005714
# 50%          0.009091
# 75%          0.012800
# max          0.150000
# Name: salario_valor_ratio, dtype: float64

# %% [markdown]
# La media de la relación salario/valor es 0.0100, lo que sugiere que, en promedio, el salario de los jugadores es aproximadamente el 1% de su valor de mercado.
# La desviación estándar es 0.0067, podemos considerar una variabilidad moderada en la relación salario/valor entre los jugadores.
# El valor mínimo es 0.0002, lo que sugiere que hay jugadores cuyo salario es una fracción muy pequeña de su valor de mercado.
# El valor máximo es 0.15, lo que indica que hay jugadores cuyo salario es significativamente mayor en comparación con su valor de mercado.
# La relación salario/valor se distribuye de manera que el 25% de los jugadores tienen una relación menor a 0.0057, el 50% a 0.0091, y el 75% a 0.0128.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# histograma de la relación salario/valor
plt.figure(figsize=(10, 6))
sns.histplot(players_16_clean['salario_valor_ratio'], bins=50, kde=True, color='blue')


plt.title('Distribución de la Relación Salario/Valor', fontsize=16)
plt.xlabel('Relación Salario/Valor', fontsize=12)
plt.ylabel('Frecuencia', fontsize=12)


plt.show()

# %%
# Jugadores con la mejor relación salario/valor
top_salario_valor = players_16_clean.sort_values('salario_valor_ratio', ascending=False).head(10)

# Jugadores con la peor relación salario/valor
bottom_salario_valor = players_16_clean.sort_values('salario_valor_ratio').head(10)


print("Mejor relación salario/valor:")
print(top_salario_valor[['short_name', 'salario_valor_ratio', 'wage_eur', 'value_eur']])

print("\nPeor relación salario/valor:")
print(bottom_salario_valor[['short_name', 'salario_valor_ratio', 'wage_eur', 'value_eur']])
# Out:
# Mejor relación salario/valor:
#            short_name  salario_valor_ratio  wage_eur  value_eur
# 11356        M. Berre             0.150000      3000      20000
# 3368       C. Barbosa             0.136364     15000     110000
# 3442       D. Álvarez             0.115385     15000     130000
# 13630        J. Byrne             0.100000      1000      10000
# 12911   M. Sokołowski             0.100000      1000      10000
# 14660  K. Kaczmarczyk             0.100000      1000      10000
# 12902      K. Ellison             0.100000      1000      10000
# 14659      J. Kolstad             0.100000      1000      10000
# 14880   B. Richardson             0.100000      1000      10000
# 9106          G. Peev             0.100000      4000      40000
#
# Peor relación salario/valor:
#              short_name  salario_valor_ratio  wage_eur  value_eur
# 2058      Iuri Medeiros             0.000200      1000    5000000
# 2508         Unai López             0.000233      1000    4300000
# ...

# %%
# correlación entre salario y valor de mercado
correlation = players_16_clean[['wage_eur', 'value_eur']].corr()

print("Correlación entre Salario y Valor de Mercado:")
print(correlation)
# Out:
# Correlación entre Salario y Valor de Mercado:
#            wage_eur  value_eur
# wage_eur   1.000000   0.907839
# value_eur  0.907839   1.000000

# %%
# Agrupar por país y calcular la media de la relación salario/valor
salario_valor_por_pais = players_16_clean.groupby('nationality')['salario_valor_ratio'].mean().sort_values(ascending=False)

# Mostrar los 10 países con mayor relación salario/valor
print(salario_valor_por_pais.head(10))

# Crear un gráfico de barras para la relación salario/valor por país
plt.figure(figsize=(12, 8))
salario_valor_por_pais.head(10).plot(kind='bar', color='purple')

# Título y etiquetas
plt.title('Top 10 Países con Mayor Relación Salario/Valor', fontsize=16)
plt.xlabel('País', fontsize=12)
plt.ylabel('Relación Salario/Valor', fontsize=12)

# Mostrar el gráfico
plt.show()
# Out:
# nationality
# Barbados             0.028333
# Bahrain              0.023077
# Kyrgyzstan           0.023077
# China PR             0.018750
# El Salvador          0.017857
# Bulgaria             0.017134
# New Caledonia        0.016754
# Antigua & Barbuda    0.015051
# India                0.015000
# Liechtenstein        0.014872
# Name: salario_valor_ratio, dtype: float64

# %%
# Agrupar por posición y calcular la media de la relación salario/valor
salario_valor_por_posicion = players_16_clean.groupby('player_positions')['salario_valor_ratio'].mean().sort_values(ascending=False)

# Mostrar las 10 posiciones con mayor relación salario/valor
print(salario_valor_por_posicion.head(10))

# Crear un gráfico de barras para la relación salario/valor por posición
plt.figure(figsize=(12, 8))
salario_valor_por_posicion.head(10).plot(kind='bar', color='orange')

# Título y etiquetas
plt.title('Top 10 Posiciones con Mayor Relación Salario/Valor', fontsize=16)
plt.xlabel('Posición', fontsize=12)
plt.ylabel('Relación Salario/Valor', fontsize=12)

# Mostrar el gráfico
plt.show()
# Out:
# player_positions
# RM, RB, LM, RWB    0.100000
# RB, CM, ST         0.100000
# CDM, CB, LB, CM    0.053571
# CM, LWB            0.025000
# LB, LWB, CB        0.025000
# CDM, LB, CB        0.025000
# LB, CM, RB, CB     0.023077
# CF, RM, LM, CDM    0.023077
# RB, RWB, CM        0.023077
# RW, RM, RWB        0.023077
# Name: salario_valor_ratio, dtype: float64

# %% [markdown]
# **DATA TRANSFORMATION**

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import pandas as pd

# %%
# columnas para normalizar
columns_to_normalize = ['wage_eur', 'value_eur', 'age', 'overall']

# transformador MinMaxScaler
scaler_minmax = MinMaxScaler()

# normalización
players_16_clean[columns_to_normalize] = scaler_minmax.fit_transform(players_16_clean[columns_to_normalize])

#  verificacion
print(players_16_clean[columns_to_normalize].head())
# Out:
#    wage_eur  value_eur       age  overall
# 0  1.000000   1.000000  0.413793     1.00
# 1  0.863388   0.770250  0.482759     0.98
# 2  0.453552   0.504460  0.517241     0.92
# 3  0.453552   0.522480  0.448276     0.92
# 4  0.544627   0.621588  0.413793     0.92
# <ipython-input-22-aab1af646f04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   players_16_clean[columns_to_normalize] = scaler_minmax.fit_transform(players_16_clean[columns_to_normalize])

# %%
# transformador StandardScaler
scaler_standard = StandardScaler()


players_16_clean[columns_to_normalize] = scaler_standard.fit_transform(players_16_clean[columns_to_normalize])

print(players_16_clean[columns_to_normalize].head())
# Out:
#     wage_eur  value_eur       age   overall
# 0  21.090414  26.013665  0.691839  3.989512
# 1  18.134254  19.939411  1.132002  3.848893
# 2   9.265774  12.912333  1.352083  3.427036
# 3   9.265774  13.388745  0.911920  3.427036
# 4  11.236547  16.009011  0.691839  3.427036
# <ipython-input-23-548557948c4e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   players_16_clean[columns_to_normalize] = scaler_standard.fit_transform(players_16_clean[columns_to_normalize])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Visualizar la distribución original de los datos
plt.figure(figsize=(12, 8))

# Subgráfico para el salario
plt.subplot(2, 2, 1)
sns.histplot(players_16_clean['wage_eur'], kde=True, color='blue')
plt.title('Distribución Salario Original')

# Subgráfico para el valor de mercado
plt.subplot(2, 2, 2)
sns.histplot(players_16_clean['value_eur'], kde=True, color='green')
plt.title('Distribución Valor de Mercado Original')

# Subgráfico para la edad
plt.subplot(2, 2, 3)
sns.histplot(players_16_clean['age'], kde=True, color='red')
plt.title('Distribución Edad Original')

# Subgráfico para la puntuación general
plt.subplot(2, 2, 4)
sns.histplot(players_16_clean['overall'], kde=True, color='orange')
plt.title('Distribución Puntuación General Original')

plt.tight_layout()
plt.show()

# %%
# Visualizar la distribución de los datos después de la transformación
plt.figure(figsize=(12, 8))

# Subgráfico para el salario normalizado/escalado
plt.subplot(2, 2, 1)
sns.histplot(players_16_clean['wage_eur'], kde=True, color='blue')
plt.title('Distribución Salario Normalizado/Escalado')

# Subgráfico para el valor de mercado normalizado/escalado
plt.subplot(2, 2, 2)
sns.histplot(players_16_clean['value_eur'], kde=True, color='green')
plt.title('Distribución Valor de Mercado Normalizado/Escalado')

# Subgráfico para la edad normalizada/escalada
plt.subplot(2, 2, 3)
sns.histplot(players_16_clean['age'], kde=True, color='red')
plt.title('Distribución Edad Normalizada/Escalada')

# Subgráfico para la puntuación general normalizada/escalada
plt.subplot(2, 2, 4)
sns.histplot(players_16_clean['overall'], kde=True, color='orange')
plt.title('Distribución Puntuación General Normalizada/Escalada')

plt.tight_layout()
plt.show()

# %%
# Guardar el conjunto de datos transformado en un nuevo archivo CSV
players_16_clean.to_csv('fifa_2020_transformed.csv', index=False)

# %%
import pandas as pd
import numpy as np
import operator
import seaborn as sns
from math import pi
import matplotlib.pyplot as plt

# %% [markdown]
# **DATA ANALISIS PLAYERS **

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd

# Cargar los datos
players_18 = pd.read_csv('/content/drive/My Drive/Colab Notebooks/fifa2020/players_18.csv')

print(players_18.head())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    sofifa_id                                         player_url  \
# 0      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 1     158023  https://sofifa.com/player/158023/lionel-messi/...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     167495  https://sofifa.com/player/167495/manuel-neuer/...
# 4     176580  https://sofifa.com/player/176580/luis-suarez/1...
#
#           short_name                            long_name  age         dob  \
# 0  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   32  1985-02-05
# 1           L. Messi       Lionel Andrés Messi Cuccittini   30  1987-06-24
# 2             Neymar        Neymar da Silva Santos Junior   25  1992-02-05
# 3           M. Neuer                         Manuel Neuer   31  1986-03-27
# 4          L. Suárez             Luis Alberto Suárez Díaz   30  1987-01-24
#
# ...

# %%
players_18.head(10)
# Out:
#    sofifa_id                                         player_url  \
# 0      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 1     158023  https://sofifa.com/player/158023/lionel-messi/...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     167495  https://sofifa.com/player/167495/manuel-neuer/...
# 4     176580  https://sofifa.com/player/176580/luis-suarez/1...
# 5     188545  https://sofifa.com/player/188545/robert-lewand...
# 6     193080  https://sofifa.com/player/193080/david-de-gea-...
# 7     183277  https://sofifa.com/player/183277/eden-hazard/1...
# 8     155862  https://sofifa.com/player/155862/sergio-ramos-...
# 9     167664  https://sofifa.com/player/167664/gonzalo-higua...
#
#           short_name                            long_name  age         dob  \
# 0  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   32  1985-02-05
# 1           L. Messi       Lionel Andrés Messi Cuccittini   30  1987-06-24
# ...

# %%
players_18.tail()
# Out:
#        sofifa_id                                         player_url  \
# 17587     237463  https://sofifa.com/player/237463/adam-kelsey/1...
# 17588     231381  https://sofifa.com/player/231381/jordan-young/...
# 17589     240404  https://sofifa.com/player/240404/jack-keeble/1...
# 17590      11728  https://sofifa.com/player/11728/barry-richards...
# 17591     235352  https://sofifa.com/player/235352/tommy-kassemo...
#
#           short_name         long_name  age         dob  height_cm  weight_kg  \
# 17587      A. Kelsey       Adam Kelsey   17  1999-11-12        188         74
# 17588       J. Young      Jordan Young   17  1999-07-31        175         71
# 17589      J. Keeble       Jack Keeble   18  1999-03-22        172         66
# 17590  B. Richardson  Barry Richardson   47  1969-08-05        185         77
# 17591   T. Käßemodel   Tommy Käßemodel   28  1988-08-09        173         75
#
#       nationality               club  ...   lwb   ldm   cdm   rdm   rwb    lb  \
# ...

# %%
players_18.shape
# Out:
# (17592, 104)

# %%
players_18.columns.values
# Out:
# array(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club', 'overall',
#        'potential', 'value_eur', 'wage_eur', 'player_positions',
#        'preferred_foot', 'international_reputation', 'weak_foot',
#        'skill_moves', 'work_rate', 'body_type', 'real_face',
#        'release_clause_eur', 'player_tags', 'team_position',
#        'team_jersey_number', 'loaned_from', 'joined',
#        'contract_valid_until', 'nation_position', 'nation_jersey_number',
#        'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic',
#        'gk_diving', 'gk_handling', 'gk_kicking', 'gk_reflexes',
#        'gk_speed', 'gk_positioning', 'player_traits',
#        'attacking_crossing', 'attacking_finishing',
#        'attacking_heading_accuracy', 'attacking_short_passing',
#        'attacking_volleys', 'skill_dribbling', 'skill_curve',
#        'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
# ...

# %%
players_18.describe()
# Out:
#            sofifa_id           age     height_cm     weight_kg       overall  \
# count   17592.000000  17592.000000  17592.000000  17592.000000  17592.000000
# mean   207461.285414     25.167804    181.262335     75.367667     66.320884
# std     32356.442078      4.616512      6.686939      6.981683      6.979345
# min       591.000000     16.000000    155.000000     49.000000     46.000000
# 25%    192353.000000     21.000000    177.000000     70.000000     62.000000
# 50%    213983.500000     25.000000    181.000000     75.000000     66.000000
# 75%    231377.250000     29.000000    186.000000     80.000000     71.000000
# max    241172.000000     47.000000    205.000000    110.000000     94.000000
#
#           potential     value_eur       wage_eur  international_reputation  \
# count  17592.000000  1.759200e+04   17592.000000              17592.000000
# mean      71.263074  2.404689e+06   11747.896771                  1.126421
# ...

# %%
players_18.dtypes
# Out:
# sofifa_id      int64
# player_url    object
# short_name    object
# long_name     object
# age            int64
#                ...
# lb            object
# lcb           object
# cb            object
# rcb           object
# rb            object
# Length: 104, dtype: object

# %% [markdown]
# **Data Wrangling**

# %%
fifa_P18= players_18[["short_name", "age", "height_cm", "weight_kg", "nationality", "club", "overall", "potential", "value_eur",
                 "wage_eur", "player_positions", "power_jumping", "power_long_shots"]]

# %%
fifa_P18.head()
# Out:
#           short_name  age  height_cm  weight_kg nationality  \
# 0  Cristiano Ronaldo   32        185         80    Portugal
# 1           L. Messi   30        170         72   Argentina
# 2             Neymar   25        175         68      Brazil
# 3           M. Neuer   31        193         92     Germany
# 4          L. Suárez   30        182         86     Uruguay
#
#                   club  overall  potential  value_eur  wage_eur  \
# 0          Real Madrid       94         94   95500000    565000
# 1         FC Barcelona       93         93  105000000    565000
# 2  Paris Saint-Germain       92         94  123000000    280000
# 3    FC Bayern München       92         92   61000000    230000
# 4         FC Barcelona       92         92   97000000    510000
#
#   player_positions power_jumping power_long_shots
# 0           LW, ST            95             92+2
# 1               RW            68               88
# 2               LW            61               77
# ...

# %%
type(fifa_P18)
# Out:
# pandas.core.frame.DataFrame

# %%
realmadrid = fifa_P18[fifa_P18["club"] == "Real Madrid"]
print(realmadrid.shape)
# Out:
# (26, 13)

# %%
realmadrid.head()
# Out:
#            short_name  age  height_cm  weight_kg nationality         club  \
# 0   Cristiano Ronaldo   32        185         80    Portugal  Real Madrid
# 8        Sergio Ramos   31        183         75       Spain  Real Madrid
# 10           T. Kroos   27        182         78     Germany  Real Madrid
# 16            G. Bale   27        183         74       Wales  Real Madrid
# 17          L. Modrić   31        174         65     Croatia  Real Madrid
#
#     overall  potential  value_eur  wage_eur player_positions power_jumping  \
# 0        94         94   95500000    565000           LW, ST            95
# 8        90         90   52000000    310000               CB          93+1
# 10       90         90   79000000    340000          CM, CDM          32-2
# 16       89         89   69500000    370000               RW            85
# 17       89         89   57000000    340000          CM, CDM            67
#
#    power_long_shots
# 0              92+2
# 8                55
# ...

# %%
barcelona = fifa_P18[fifa_P18["club"] == "FC Barcelona"]
print(barcelona.shape)
# Out:
# (24, 13)

# %%
barcelona.head()
# Out:
#          short_name  age  height_cm  weight_kg nationality          club  \
# 1          L. Messi   30        170         72   Argentina  FC Barcelona
# 4         L. Suárez   30        182         86     Uruguay  FC Barcelona
# 37            Piqué   30        194         85       Spain  FC Barcelona
# 40       I. Rakitić   29        184         78     Croatia  FC Barcelona
# 66  Sergio Busquets   28        189         76       Spain  FC Barcelona
#
#     overall  potential  value_eur  wage_eur player_positions power_jumping  \
# 1        93         93  105000000    565000               RW            68
# 4        92         92   97000000    510000               ST            69
# 37       87         87   37500000    240000               CB            74
# 40       87         87   48500000    275000               CM          44-7
# 66       86         86   36000000    250000          CDM, CM            66
#
#    power_long_shots
# 1                88
# 4                86
# ...

# %% [markdown]
# **Data Transformation

# %% [markdown]
# MEJORES JUGADORES REAL MADRID VS BARCELONA

# %%
plt.figure()

plt.subplot(121)
plt.boxplot(realmadrid["overall"])
plt.ylabel("Overall")
plt.title("Real Madrid")
plt.grid(True)

plt.subplot(122)
plt.boxplot(barcelona["overall"])
plt.title("Barcelona")
plt.grid(True)

# %% [markdown]
# En esta grafica podemos ver una comparacion entre los mejores jugadores Real Madrid vs Barcelona, esto tomando en cuenta la calificacion o rubro dado a cada jugador (overall), podemos ver que la calificacion de los jugadores del real madrid esta un poco mas dispersa que los del barcelona, esto quiere decir que la calificacion de los de barcelona es un poco mas concentrada en comparacion a los del otro club.

# %%
print(realmadrid["overall"].describe())
print(barcelona["overall"].describe())
# Out:
# count    26.000000
# mean     81.038462
# std       7.886600
# min      64.000000
# 25%      77.000000
# 50%      83.000000
# 75%      86.000000
# max      94.000000
# Name: overall, dtype: float64
# count    24.000000
# mean     82.375000
# std       4.789595
# min      70.000000
# 25%      80.750000
# 50%      82.000000
# 75%      85.000000
# max      93.000000
# Name: overall, dtype: float64

# %% [markdown]
# para poder ver con claridad de forma estadistica tenemos ahora que tienen un promedio bastante parecido ambos clubs, sin embargo el barcelona tiene un overall un poco mayor, siento de 82.3, teniendo tambien una desviacion estandar mucho menor (4.78) en comparacion al real madrid que tiene una std de 7.8

# %% [markdown]
# JUGADORES MEJOR VALORADOS -  REAL MADRID VS BARCELONA

# %%
realmadrid["value_eur"].describe()
# Out:
# count    2.600000e+01
# mean     3.179808e+07
# std      2.591052e+07
# min      5.500000e+05
# 25%      1.000000e+07
# 50%      2.800000e+07
# 75%      4.637500e+07
# max      9.550000e+07
# Name: value_eur, dtype: float64

# %%
plt.hist(realmadrid["value_eur"])
plt.xlabel("Valor en 10x8 de millones de Euros")
plt.ylabel("Frecuencia")
plt.title("Valor en 10x8 de millones de Euros - Real Madrid")
# Out:
# Text(0.5, 1.0, 'Valor en 10x8 de millones de Euros - Real Madrid')

# %%
barcelona["value_eur"].describe()
# Out:
# count    2.400000e+01
# mean     2.979167e+07
# std      2.479609e+07
# min      2.000000e+06
# 25%      1.687500e+07
# 50%      2.200000e+07
# 75%      3.562500e+07
# max      1.050000e+08
# Name: value_eur, dtype: float64

# %%
plt.hist(barcelona["value_eur"])
plt.xlabel("Valor en 10x8 de millones de Euros")
plt.ylabel("Frecuencia")
plt.title("Valor en 10x8 de millones de Euros - Barcelona")
# Out:
# Text(0.5, 1.0, 'Valor en 10x8 de millones de Euros - Barcelona')

# %% [markdown]
# Con las estadisticas basicas podemos ver que el real madrid tiene un promedio mayor en cuanto a la valoracion de sus jugadores

# %%
mostvalue_rm = realmadrid[realmadrid["value_eur"] > 50000000]
mostvalue_rm
# Out:
#            short_name  age  height_cm  weight_kg nationality         club  \
# 0   Cristiano Ronaldo   32        185         80    Portugal  Real Madrid
# 8        Sergio Ramos   31        183         75       Spain  Real Madrid
# 10           T. Kroos   27        182         78     Germany  Real Madrid
# 16            G. Bale   27        183         74       Wales  Real Madrid
# 17          L. Modrić   31        174         65     Croatia  Real Madrid
# 46               Isco   25        176         74       Spain  Real Madrid
#
#     overall  potential  value_eur  wage_eur player_positions power_jumping  \
# 0        94         94   95500000    565000           LW, ST            95
# 8        90         90   52000000    310000               CB          93+1
# 10       90         90   79000000    340000          CM, CDM          32-2
# 16       89         89   69500000    370000               RW            85
# ...

# %%
# @title player_positions

from matplotlib import pyplot as plt
import seaborn as sns
mostvalue_rm.groupby('player_positions').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title short_name vs age

from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(mostvalue_rm['short_name'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(mostvalue_rm, x='age', y='short_name', inner='stick', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
# Out:
# <ipython-input-95-b0e1b3f399a7>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(mostvalue_rm, x='age', y='short_name', inner='stick', palette='Dark2')

# %%
mostvalue_bz = barcelona[barcelona["value_eur"] > 50000000]
mostvalue_bz
# Out:
#   short_name  age  height_cm  weight_kg nationality          club  overall  \
# 1   L. Messi   30        170         72   Argentina  FC Barcelona       93
# 4  L. Suárez   30        182         86     Uruguay  FC Barcelona       92
#
#    potential  value_eur  wage_eur player_positions power_jumping  \
# 1         93  105000000    565000               RW            68
# 4         92   97000000    510000               ST            69
#
#   power_long_shots
# 1               88
# 4               86

# %%
# @title player_positions

from matplotlib import pyplot as plt
import seaborn as sns
mostvalue_bz.groupby('player_positions').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# EDADES VS VALORACIONES

# %%
fifa_P18.plot(kind = "scatter", x = "age", y = "value_eur")
# Out:
# <Axes: xlabel='age', ylabel='value_eur'>

# %% [markdown]
# Podemos observar una mayore rentabilidad en el mercado entre los 20 - 30 años

# %% [markdown]
# JUGADORES MAS VALIOSOS

# %%
fifa_P18.describe()
# Out:
#                 age     height_cm     weight_kg       overall     potential  \
# count  17592.000000  17592.000000  17592.000000  17592.000000  17592.000000
# mean      25.167804    181.262335     75.367667     66.320884     71.263074
# std        4.616512      6.686939      6.981683      6.979345      6.084853
# min       16.000000    155.000000     49.000000     46.000000     46.000000
# 25%       21.000000    177.000000     70.000000     62.000000     67.000000
# 50%       25.000000    181.000000     75.000000     66.000000     71.000000
# 75%       29.000000    186.000000     80.000000     71.000000     75.000000
# max       47.000000    205.000000    110.000000     94.000000     94.000000
#
#           value_eur       wage_eur
# count  1.759200e+04   17592.000000
# mean   2.404689e+06   11747.896771
# std    5.381958e+06   23260.653038
# min    0.000000e+00       0.000000
# 25%    3.250000e+05    2000.000000
# 50%    7.000000e+05    4000.000000
# ...

# %%
mostvalue_world = fifa_P18[fifa_P18["value_eur"] > 80000000]
print(fifa_P18.shape)
print(mostvalue_world.shape)
mostvalue_world
# Out:
# (17592, 13)
# (7, 13)
#            short_name  age  height_cm  weight_kg nationality  \
# 0   Cristiano Ronaldo   32        185         80    Portugal
# 1            L. Messi   30        170         72   Argentina
# 2              Neymar   25        175         68      Brazil
# 4           L. Suárez   30        182         86     Uruguay
# 5      R. Lewandowski   28        185         79      Poland
# 7           E. Hazard   26        173         76     Belgium
# 12       K. De Bruyne   26        181         68     Belgium
#
#                    club  overall  potential  value_eur  wage_eur  \
# 0           Real Madrid       94         94   95500000    565000
# 1          FC Barcelona       93         93  105000000    565000
# 2   Paris Saint-Germain       92         94  123000000    280000
# 4          FC Barcelona       92         92   97000000    510000
# 5     FC Bayern München       91         91   92000000    355000
# ...

# %% [markdown]
# Tomando en cuenta los valores estadisticos en relacion al valor de cada jugador, vemos que lso jugadores mas valiosos los primero 3 lugares son de  Cristiano Ronaldo, Leonel Messi y Neymar,  sin embargo podemos ver los primero 7 jugadores mejor pagados o valorador

# %%
realmadrid["wage_eur"].describe()
# Out:
# count        26.000000
# mean     182730.769231
# std      130348.934078
# min       10000.000000
# 25%       93750.000000
# 50%      170000.000000
# 75%      250000.000000
# max      565000.000000
# Name: wage_eur, dtype: float64

# %%
barcelona["wage_eur"].describe()
# Out:
# count        24.000000
# mean     188833.333333
# std      117822.883533
# min       47000.000000
# 25%      132500.000000
# 50%      150000.000000
# 75%      181250.000000
# max      565000.000000
# Name: wage_eur, dtype: float64

# %%
best_wage_rm = realmadrid[realmadrid["wage_eur"] > 300000]
best_wage_rm
# Out:
#            short_name  age  height_cm  weight_kg nationality         club  \
# 0   Cristiano Ronaldo   32        185         80    Portugal  Real Madrid
# 8        Sergio Ramos   31        183         75       Spain  Real Madrid
# 10           T. Kroos   27        182         78     Germany  Real Madrid
# 16            G. Bale   27        183         74       Wales  Real Madrid
# 17          L. Modrić   31        174         65     Croatia  Real Madrid
#
#     overall  potential  value_eur  wage_eur player_positions power_jumping  \
# 0        94         94   95500000    565000           LW, ST            95
# 8        90         90   52000000    310000               CB          93+1
# 10       90         90   79000000    340000          CM, CDM          32-2
# 16       89         89   69500000    370000               RW            85
# 17       89         89   57000000    340000          CM, CDM            67
#
#    power_long_shots
# 0              92+2
# 8                55
# ...

# %%
best_wage_bz = barcelona[barcelona["wage_eur"] > 300000]
best_wage_bz
# Out:
#   short_name  age  height_cm  weight_kg nationality          club  overall  \
# 1   L. Messi   30        170         72   Argentina  FC Barcelona       93
# 4  L. Suárez   30        182         86     Uruguay  FC Barcelona       92
#
#    potential  value_eur  wage_eur player_positions power_jumping  \
# 1         93  105000000    565000               RW            68
# 4         92   97000000    510000               ST            69
#
#   power_long_shots
# 1               88
# 4               86

# %% [markdown]
# JUGADOR CON MEJOR SALARIO FIFA 20 -PLAYERS18

# %%
fifa_P18["wage_eur"].describe()
# Out:
# count     17592.000000
# mean      11747.896771
# std       23260.653038
# min           0.000000
# 25%        2000.000000
# 50%        4000.000000
# 75%       12000.000000
# max      565000.000000
# Name: wage_eur, dtype: float64

# %%
best_wage_world = fifa_P18[fifa_P18["wage_eur"] > 250000]
best_wage_world
# Out:
#            short_name  age  height_cm  weight_kg nationality  \
# 0   Cristiano Ronaldo   32        185         80    Portugal
# 1            L. Messi   30        170         72   Argentina
# 2              Neymar   25        175         68      Brazil
# 4           L. Suárez   30        182         86     Uruguay
# 5      R. Lewandowski   28        185         79      Poland
# 7           E. Hazard   26        173         76     Belgium
# 8        Sergio Ramos   31        183         75       Spain
# 9          G. Higuaín   29        184         87   Argentina
# 10           T. Kroos   27        182         78     Germany
# 12       K. De Bruyne   26        181         68     Belgium
# 15          S. Agüero   29        173         70   Argentina
# 16            G. Bale   27        183         74       Wales
# 17          L. Modrić   31        174         65     Croatia
# 18         A. Sánchez   28        169         62       Chile
# ...

# %%
plt.hist(fifa_P18["power_long_shots"])
plt.xlabel("Potencia en Tiros Largos")
plt.ylabel("Frecuencia")
plt.title("Potencia en Tiros Largos")
# Out:
# Text(0.5, 1.0, 'Potencia en Tiros Largos')

# %% [markdown]
# JUGADORES CON MAYOR EDAD

# %%
fifa_P18["age"].describe()
# Out:
# count    17592.000000
# mean        25.167804
# std          4.616512
# min         16.000000
# 25%         21.000000
# 50%         25.000000
# 75%         29.000000
# max         47.000000
# Name: age, dtype: float64

# %% [markdown]
# Podemos observar que el promedio de edad se encuentra entre los 25 años

# %%
age_old = fifa_P18[fifa_P18["age"] > 40]
age_old
# Out:
#           short_name  age  height_cm  weight_kg nationality  \
# 4406        O. Pérez   44        172         75      Mexico
# 5489    E. El Hadary   44        188         87       Egypt
# 6200            Quim   41        182         80    Portugal
# 15198         C. Day   41        188         85     England
# 16629       D. Coyne   43        183         83       Wales
# 16630      J. Walker   43        180         84     England
# 17590  B. Richardson   47        185         77     England
#
#                     club  overall  potential  value_eur  wage_eur  \
# 4406             Pachuca       71         71     160000      9000
# 5489          Al Taawoun       70         70     120000      7000
# 6200             CD Aves       69         69      70000      3000
# 15198          Stevenage       59         59      10000      1000
# 16629         Shrewsbury       55         55      10000      1000
# 16630       Lincoln City       55         55      10000      1000
# ...

# %%
age_old = fifa_P18[fifa_P18["age"] <20]
age_old
# Out:
#           short_name  age  height_cm  weight_kg    nationality  \
# 126        K. Mbappé   18        178         73         France
# 196    G. Donnarumma   18        196         90          Italy
# 392      M. Rashford   19        185         70        England
# 690       C. Pulisic   18        172         69  United States
# 692       K. Dolberg   19        187         82        Denmark
# ...              ...  ...        ...        ...            ...
# 17585      L. Sackey   18        182         72          Ghana
# 17586   J. Lundstram   18        176         61        England
# 17587      A. Kelsey   17        188         74        England
# 17588       J. Young   17        175         71       Scotland
# 17589      J. Keeble   18        172         66        England
#
#                       club  overall  potential  value_eur  wage_eur  \
# 126    Paris Saint-Germain       83         94   41500000     31000
# 196                  Milan       82         94   28500000     35000
# ...

# %%
import matplotlib.pyplot as plt

# Filtrar los jugadores con valor superior a 50 millones de euros
mostvalue_rm = realmadrid[realmadrid["value_eur"] > 50000000]

# Ordenar por valor de manera descendente
mostvalue_rm = mostvalue_rm.sort_values(by="value_eur", ascending=False)

# Crear el gráfico de barras
plt.figure(figsize=(10, 6))
plt.barh(mostvalue_rm['short_name'], mostvalue_rm['value_eur'], color='royalblue')

# Añadir etiquetas y título
plt.xlabel('Valor en euros (€)', fontsize=12)
plt.ylabel('Jugador', fontsize=12)
plt.title('Jugadores más valiosos de Real Madrid (Valor > 50M €)', fontsize=14)
plt.gca().invert_yaxis()  # Para que el jugador más valioso esté en la parte superior

# Mostrar el gráfico
plt.show()

# %%
import matplotlib.pyplot as plt

# Filtrar los jugadores con un salario superior a 250,000 euros
best_wage_world = fifa_P18[fifa_P18["wage_eur"] > 250000]

# Ordenar por salario de manera descendente
best_wage_world = best_wage_world.sort_values(by="wage_eur", ascending=False)

# Crear el gráfico de barras
plt.figure(figsize=(10, 6))
plt.barh(best_wage_world['short_name'], best_wage_world['wage_eur'], color='green')

# Añadir etiquetas y título
plt.xlabel('Salario en euros (€)', fontsize=12)
plt.ylabel('Jugador', fontsize=12)
plt.title('Jugadores con los Salarios Más Altos en FIFA 2020 (Valor > 250K €)', fontsize=14)
plt.gca().invert_yaxis()  # Para que el jugador con el salario más alto esté en la parte superior

# Mostrar el gráfico
plt.show()

# %%
# Encontrar el jugador con la mayor potencia en tiros largos
max_power_player = fifa_P18.loc[fifa_P18["power_long_shots"].idxmax()]

# Mostrar el jugador y su valor de potencia en tiros largos
print("Jugador con más potencia en tiros largos:")
print(f"Nombre: {max_power_player['short_name']}")
print(f"Potencia en Tiros Largos: {max_power_player['power_long_shots']}")
# Out:
# Jugador con más potencia en tiros largos:
# Nombre: Cristiano Ronaldo
# Potencia en Tiros Largos: 92+2

# %%
# Ordenar el DataFrame por la columna 'power_long_shots' de manera descendente
top_5_long_shots = fifa_P18[['short_name', 'power_long_shots']].sort_values(by='power_long_shots', ascending=False).head(5)

# Mostrar los primeros 5 jugadores con la mejor potencia en tiros largos
print("Los 5 jugadores con mejor potencia en tiros largos:")
print(top_5_long_shots)
# Out:
# Los 5 jugadores con mejor potencia en tiros largos:
#              short_name power_long_shots
# 0     Cristiano Ronaldo             92+2
# 49         J. Rodríguez               91
# 10             T. Kroos             90+2
# 16              G. Bale               90
# 3214           V. Ayala               90

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Crear el gráfico de dispersión
plt.figure(figsize=(10, 6))

# Usar un gráfico de dispersión de Matplotlib
plt.scatter(fifa_P18['power_long_shots'], fifa_P18['wage_eur'], color='blue', alpha=0.5)

# Añadir etiquetas y título
plt.xlabel('Potencia en Tiros Largos', fontsize=12)
plt.ylabel('Sueldo en euros (€)', fontsize=12)
plt.title('Relación entre Potencia en Tiros Largos y Sueldo de los Jugadores', fontsize=14)

# Mostrar el gráfico
plt.show()

# %%
# Seleccionar los primeros 10 jugadores con mejor potencia en tiros largos
top_10_long_shots = fifa_P18[['short_name', 'power_long_shots', 'wage_eur']] \
    .sort_values(by='power_long_shots', ascending=False) \
    .head(10)

# Mostrar solo los sueldos de los primeros 10 jugadores
print("Los sueldos de los primeros 10 jugadores con mejor potencia en tiros largos:")
print(top_10_long_shots[['short_name', 'wage_eur']])
# Out:
# Los sueldos de los primeros 10 jugadores con mejor potencia en tiros largos:
#               short_name  wage_eur
# 0      Cristiano Ronaldo    565000
# 49          J. Rodríguez    250000
# 10              T. Kroos    340000
# 16               G. Bale    370000
# 3214            V. Ayala     38000
# 8188         Paulo Lopes      3000
# 108          R. Fährmann     54000
# 15945    F. Pizzicanella      1000
# 15388           N. Kocik      1000
# 17470         M. Iversen      1000

# %%
import matplotlib.pyplot as plt

# Seleccionar los primeros 10 jugadores con mejor potencia en tiros largos
top_5_long_shots = fifa_P18[['short_name', 'power_long_shots', 'wage_eur']] \
    .sort_values(by='power_long_shots', ascending=False) \
    .head(5)

# Crear el gráfico de barras
plt.figure(figsize=(15, 6))
plt.barh(top_5_long_shots['short_name'], top_5_long_shots['wage_eur'], color='orange')

# Etiquetas y título
plt.xlabel('Sueldo en euros (€)', fontsize=12)
plt.ylabel('Jugador', fontsize=12)
plt.title('Sueldo de los 10 Jugadores con Mejor Potencia en Tiros Largos', fontsize=14)

# Mostrar el gráfico
plt.show()

# %%
# Agrupar por posición y calcular la calificación promedio
avg_rating_by_position = fifa_P18.groupby('player_positions')['overall'].mean().sort_values(ascending=False)

# Mostrar el resultado
print(avg_rating_by_position)
# Out:
# player_positions
# CF, RW, CAM, ST    86.0
# CF, LW, ST         85.0
# CAM, RM, LM, LW    84.0
# CM, LW, RW         83.0
# LW, RW, CAM, LM    83.0
#                    ...
# CM, CF, CAM        53.0
# RW, CAM, ST, LW    52.0
# CM, LM, RM, ST     52.0
# RB, LM, RM         50.0
# RW, RB, LB         46.0
# Name: overall, Length: 796, dtype: float64

# %%
# Crear una nueva columna con la primera posición del jugador
fifa_P18['primary_position'] = fifa_P18['player_positions'].str.split(',').str[0]

# Agrupar por la primera posición y calcular la calificación promedio
avg_rating_by_position = fifa_P18.groupby('primary_position')['overall'].mean().sort_values(ascending=False)

# Mostrar el resultado
print(avg_rating_by_position)
# Out:
# primary_position
# CDM    67.524265
# LW     67.317568
# CF     67.304878
# CAM    67.050893
# CB     66.979125
# RW     66.936556
# LM     66.790607
# RM     66.391841
# RB     66.272590
# ST     66.099688
# LWB    66.078947
# LB     66.002222
# RWB    65.850000
# CM     65.538186
# GK     64.779687
# Name: overall, dtype: float64
# <ipython-input-142-1bfbb72511eb>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fifa_P18['primary_position'] = fifa_P18['player_positions'].str.split(',').str[0]

# %%
import matplotlib.pyplot as plt

# Crear el gráfico de barras
plt.figure(figsize=(10, 6))
avg_rating_by_position.plot(kind='bar', color='skyblue')

# Añadir etiquetas y título
plt.xlabel('Posición', fontsize=12)
plt.ylabel('Calificación Promedio', fontsize=12)
plt.title('Calificación Promedio por Posición en FIFA 18', fontsize=14)

# Mostrar el gráfico
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Agrupar por posición y calcular la calificación promedio
avg_rating_by_position = fifa_P18.groupby('player_positions')['overall'].mean().sort_values(ascending=False)

# Crear el gráfico de barras
plt.figure(figsize=(12, 8))
avg_rating_by_position.plot(kind='bar', color='skyblue')

# Añadir etiquetas y título
plt.xlabel('Posición', fontsize=12)
plt.ylabel('Calificación Promedio', fontsize=12)
plt.title('Calificación Promedio por Posición en FIFA 18', fontsize=14)

# Mostrar el gráfico
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Agrupar por posición y calcular la calificación promedio
avg_rating_by_position = fifa_P18.groupby('player_positions')['overall'].mean().sort_values(ascending=False)

# Seleccionar las primeras 10 posiciones con la mejor calificación
top_10_positions = avg_rating_by_position.head(10)

# Crear el gráfico de barras
plt.figure(figsize=(12, 8))
top_10_positions.plot(kind='bar', color='skyblue')

# Añadir etiquetas y título
plt.xlabel('Posición', fontsize=12)
plt.ylabel('Calificación Promedio', fontsize=12)
plt.title('Top 10 Posiciones Mejor Calificadas en FIFA 18', fontsize=14)

# Mostrar el gráfico
plt.tight_layout()
plt.show()

# %%
# Extraer solo la primera posición de la columna 'player_positions'
fifa_P18['primary_position'] = fifa_P18['player_positions'].str.split(',').str[0]

# Agrupar por la primera posición y calcular la calificación promedio
avg_rating_by_position = fifa_P18.groupby('primary_position')['overall'].mean().sort_values(ascending=False)

# Mostrar el resultado
print(avg_rating_by_position)
# Out:
# primary_position
# CDM    67.524265
# LW     67.317568
# CF     67.304878
# CAM    67.050893
# CB     66.979125
# RW     66.936556
# LM     66.790607
# RM     66.391841
# RB     66.272590
# ST     66.099688
# LWB    66.078947
# LB     66.002222
# RWB    65.850000
# CM     65.538186
# GK     64.779687
# Name: overall, dtype: float64
# <ipython-input-146-af5b8325a7c6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fifa_P18['primary_position'] = fifa_P18['player_positions'].str.split(',').str[0]

# %%
# Crear una nueva fila para cada posición
expanded_fifa = fifa_P18.explode('player_positions')

# Agrupar por cada posición y calcular la calificación promedio
avg_rating_by_position_expanded = expanded_fifa.groupby('player_positions')['overall'].mean().sort_values(ascending=False)

# Mostrar el resultado
print(avg_rating_by_position_expanded)
# Out:
# player_positions
# CF, RW, CAM, ST    86.0
# CF, LW, ST         85.0
# CAM, RM, LM, LW    84.0
# CM, LW, RW         83.0
# LW, RW, CAM, LM    83.0
#                    ...
# CM, CF, CAM        53.0
# RW, CAM, ST, LW    52.0
# CM, LM, RM, ST     52.0
# RB, LM, RM         50.0
# RW, RB, LB         46.0
# Name: overall, Length: 796, dtype: float64

# %%
# Extraer solo la primera posición de la columna 'player_positions'
fifa_P18['primary_position'] = fifa_P18['player_positions'].str.split(',').str[0]

# Agrupar por la primera posición y calcular la calificación promedio
avg_rating_by_position = fifa_P18.groupby('primary_position')['overall'].mean().sort_values(ascending=False)

# Mostrar el resultado
print(avg_rating_by_position)
# Out:
# primary_position
# CDM    67.524265
# LW     67.317568
# CF     67.304878
# CAM    67.050893
# CB     66.979125
# RW     66.936556
# LM     66.790607
# RM     66.391841
# RB     66.272590
# ST     66.099688
# LWB    66.078947
# LB     66.002222
# RWB    65.850000
# CM     65.538186
# GK     64.779687
# Name: overall, dtype: float64
# <ipython-input-148-af5b8325a7c6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fifa_P18['primary_position'] = fifa_P18['player_positions'].str.split(',').str[0]

# %%
import matplotlib.pyplot as plt

# Los datos de calificación promedio por posición
avg_rating_by_position = {
    'CDM': 67.52,
    'LW': 67.32,
    'CF': 67.30,
    'CAM': 67.05,
    'CB': 66.98,
    'RW': 66.94,
    'LM': 66.79,
    'RM': 66.39,
    'RB': 66.27,
    'ST': 66.10,
    'LWB': 66.08,
    'LB': 66.00,
    'RWB': 65.85,
    'CM': 65.54,
    'GK': 64.78
}

# Convertir a un DataFrame para mayor flexibilidad (opcional)
import pandas as pd
avg_rating_by_position_df = pd.Series(avg_rating_by_position).sort_values(ascending=False)

# Crear el gráfico de barras
plt.figure(figsize=(12, 8))
avg_rating_by_position_df.plot(kind='bar', color='skyblue')

# Añadir etiquetas y título
plt.xlabel('Posición', fontsize=12)
plt.ylabel('Calificación Promedio', fontsize=12)
plt.title('Calificación Promedio por Posición en FIFA 18', fontsize=14)

# Mostrar el gráfico
plt.tight_layout()
plt.show()
