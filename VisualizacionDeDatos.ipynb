# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
stock_returns = pd.read_csv('/content/drive/My Drive/Colab Notebooks/DataAnalysis/stocks_daily_returns.csv')

# %%
stock_prices  = pd.read_csv('/content/drive/My Drive/Colab Notebooks/DataAnalysis/stocks_daily_prices.csv')

# %%
print(stock_prices.head())
# Out:
#        Date      AAPL        JPM         PG        UAL
# 0  1/2/2008  5.949703  29.448614  47.058838  29.915234
# 1  1/3/2008  5.952452  29.246094  47.058838  29.690800
# 2  1/4/2008  5.498071  28.582682  46.870098  31.000002
# 3  1/7/2008  5.424478  28.868999  47.175980  29.180000
# 4  1/8/2008  5.229351  27.723747  47.299629  24.389999

# %%
print(stock_returns.head())
# Out:
#        Date      AAPL       JPM        PG        UAL
# 0  1/2/2008  0.000000  0.000000  0.000000   0.000000
# 1  1/3/2008  0.046203 -0.687708  0.000000  -0.750233
# 2  1/4/2008 -7.633517 -2.268378 -0.401072   4.409454
# 3  1/7/2008 -1.338518  1.001718  0.652615  -5.870973
# 4  1/8/2008 -3.597157 -3.967066  0.262103 -16.415356

# %%
plt.figure(figsize=(10, 6))
plt.plot(stock_prices['Date'], stock_prices['JPM'], label='JP Morgan')
plt.plot(stock_prices['Date'], stock_prices['PG'], label='P&G')
plt.plot(stock_prices['Date'], stock_prices['AAPL'], label='Apple')
plt.plot(stock_prices['Date'], stock_prices['UAL'], label='United Airlines')


plt.xlabel('Fecha')
plt.ylabel('Precio de la acción')
plt.title('Precios diarios de acciones')
plt.legend()
plt.xticks(rotation=45)
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 8))


axes[0, 0].plot(stock_prices['Date'], stock_prices['JPM'], color='blue')
axes[0, 0].set_title('JP Morgan')
axes[0, 1].plot(stock_prices['Date'], stock_prices['PG'], color='green')
axes[0, 1].set_title('Procter & Gamble')
axes[1, 0].plot(stock_prices['Date'], stock_prices['AAPL'], color='orange')
axes[1, 0].set_title('Apple')
axes[1, 1].plot(stock_prices['Date'], stock_prices['UAL'], color='red')
axes[1, 1].set_title('United Airlines')


for ax in axes.flat:
    ax.set(xlabel='Fecha', ylabel='Precio de la acción')
    ax.tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 4, figsize=(16, 4))


axes[0].plot(stock_prices['Date'], stock_prices['JPM'], color='blue')
axes[0].set_title('JP Morgan')
axes[1].plot(stock_prices['Date'], stock_prices['PG'], color='green')
axes[1].set_title('P&G')
axes[2].plot(stock_prices['Date'], stock_prices['AAPL'], color='orange')
axes[2].set_title('Apple')
axes[3].plot(stock_prices['Date'], stock_prices['UAL'], color='red')
axes[3].set_title('United Airlines')


for ax in axes:
    ax.set(xlabel='Fecha', ylabel='Precio de la acción')
    ax.tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.scatter(stock_returns['AAPL'], stock_returns['JPM'], alpha=0.5)
plt.xlabel('Retornos de Apple')
plt.ylabel('Retornos de JP Morgan')
plt.title('Diagrama de dispersión entre los retornos de Apple y JP Morgan')
plt.show()

# %%
import seaborn as sns


plt.figure(figsize=(8, 6))
sns.scatterplot(data=stock_returns, x='AAPL', y='JPM')
plt.title('Diagrama de dispersión entre los retornos de Apple y JP Morgan (Seaborn)')
plt.show()

# %%
labels = ['AAPL', 'JP Morgan', 'P&G', 'United Airlines']
sizes = [70, 10, 10, 10]
explode = (0.1, 0, 0, 0)


plt.figure(figsize=(7, 7))
plt.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Asignaciones de activos')
plt.show()

# %%
plt.figure(figsize=(10, 6))


plt.hist(stock_returns['UAL'], bins=40, alpha=0.5, color='red', label='United Airlines')


plt.hist(stock_returns['PG'], bins=40, alpha=0.5, color='blue', label='P&G')


ual_mean = stock_returns['UAL'].mean()

ual_std = stock_returns['UAL'].std()
